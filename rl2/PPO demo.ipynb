# %% [markdown]
# # load packages

# %%
import os
import json

import argparse
import warnings
import random

import numpy as np
import sys
sys.path.insert(0, '..')
import torch

from distutils.dir_util import copy_tree

from rl2 import collectors, envs, agents, models, defaults
from rl2.utils.distributions import CategoricalHead, ScalarHead

import rl2.utils.common as common
from rl2.agents.agent import AbstractAgent
from rl2.modules.deepmind import DeepMindEnc

# %%
from rl2.envs.gym.atari import make_atari

# %% [markdown]
# # choose your env

# %%
seed = 42
env = 'atari'
env_id = 'Breakout'

# %% [markdown]
# # constants

# %%
eps = 1e-8
inf = 1e8

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# # make env

# %%
env = make_atari(env_id+'NoFrameskip-v4', 1, 42)
# Out:
# WARNING:tensorflow:From /Users/anthony/Repo/baselines/baselines/common/misc_util.py:58: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.

# %% [markdown]
# # Base class
#
# inherit this class to implement your agent

# %%
class GeneralAgent(AbstractAgent):
    name = 'General'

    def __init__(self, model, collector, epoch):
#         self.args = args
        self.model = model
        self.epoch = epoch
        self.collector = collector
#         self.logger = Logger(self.name, args=args)

#         self.info = EvaluationMetrics([
#             'Time/Step',
#             'Time/Item',
#             'Loss/Total',
#             'Loss/Value',
#             'Values/Reward',
#             'Values/Value',
#             'Score/Train',
#         ])

    def loss_func(self, *args, **kwargs):
        raise NotImplementedError

    def train(self):
        self.collector.step_env()
        for epoch in range(self.epoch):
            self.collector.reset_count()
            while self.collector.has_next():
                data = self.collector.step()
                loss = self.loss_func(*data, info=self.info)
                self.model.step(loss)

# %% [markdown]
# # Your implementation
#
# example ppo

# %%
class PPOAgent(GeneralAgent):
    name = 'PPO'

    def __init__(self,
                 model,
                 collector,
                 epoch=4,
                 vf_coef=0.5,
                 ent_coef=0.01,
                 cliprange=0.1):
        super().__init__(model=model, collector=collector, epoch=epoch)

        self.vf_coef = vf_coef
        self.ent_coef = ent_coef

        self.cliprange = cliprange

#         self.metrics.set([
#             'Loss/Policy',
#             'Values/Entropy',
#             'Values/Adv',
#         ])

    def loss_func(self, obs, old_acs, old_nlps, advs, old_rets):
        ac_dist, val_dist = self.model.forward(obs)
        vals = val_dist.mean
        nlps = -ac_dist.log_prob(old_acs)
        ent = ac_dist.entropy().mean()
        old_vals = old_rets - advs

        advs = (advs - advs.mean()) / (advs.std() + settings.EPS)

        vals_clipped = (old_vals + torch.clamp(vals - old_vals,
                                               -self.cliprange,
                                               self.cliprange))

        vf_loss_clipped = 0.5 * (vals_clipped - old_rets.detach()).pow(2)
        vf_loss = 0.5 * (vals - old_rets.detach()).pow(2)

        vf_loss = torch.max(vf_loss, vf_loss_clipped).mean()

        ratio = torch.exp(old_nlps - nlps).unsqueeze(-1)
        pg_loss1 = -advs * ratio

        ratio = torch.clamp(ratio, 1 - self.cliprange, 1 + self.cliprange)
        pg_loss2 = -advs * ratio

        pg_loss = torch.max(pg_loss1, pg_loss2).mean()

        # Total loss
        loss = pg_loss - self.ent_coef * ent + self.vf_coef * vf_loss

        if self.metrics is not None:
            self.metrics.update('Values/Value', vals.mean().item())
            self.metrics.update('Values/Adv', advs.mean().item())
            self.metrics.update('Values/Entropy', ent.item())
            self.metrics.update('Loss/Value', vf_loss.item())
            self.metrics.update('Loss/Policy', pg_loss.item())
            self.metrics.update('Loss/Total', loss.item())

        return loss

# %% [markdown]
# ppo

# %%
input_shape = env.observation_space.shape

# %% [markdown]
# reshape from tf to pt

# %%
if len(input_shape) > 1:
    input_shape = (input_shape[-1], *input_shape[:-1])

# %% [markdown]
# networks

# %%
from torch import nn

# %%
# class CategoricalHead(nn.Module):
#     def __init__(self, input_size, out_size):
#         super().__init__()
#         self.linear = nn.Linear(input_size, out_size)

#     def forward(self, x):
#         x = self.linear(x)
#         dist = Categorical(logits=F.log_softmax(x, dim=-1))
#         return dist

# %%
# class ScalarHead(nn.Module):
#     def __init__(self, input_size, out_size):
#         super().__init__()
#         self.linear = nn.Linear(input_size, out_size)

#     def forward(self, x):
#         x = self.linear(x)
#         dist = ScalarDist(x)
#         return dist

# %%
encoder = DeepMindEnc(input_shape).to(device)
actor = CategoricalHead(encoder.out_shape, env.action_space.n)
critic = ScalarHead(encoder.out_shape, 1)

networks = [encoder, actor, critic]

# %%
# Declare optimizer
optimizer = 'torch.optim.Adam'

# %%
# Create a model using the necessary networks
model = models.ActorCriticModel(networks, optimizer)

# %%
# Create a collector for managing data collection
collector = collectors.PGCollector(env, model, device)

# %%
agent = PPOAgent(model, collector)

# %%
from tqdm import tqdm

# %%
# # Finally create an agent with the defined components
# train(args, 'PPOAgent', 'ppo', model, collector)
steps = int(5e7)
steps = steps // collector.num_workers + 1
for step in tqdm(range(5)):
#     if train_fn is None:
    agent.train()
#     else:
#         train_fn(agent, step, steps)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0194]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0194]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0189]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0190]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0190]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0195]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0195]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0196]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0190]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0194]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0194]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0195]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0197]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0194]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0190]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0189]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0190]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0188]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0190]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0189]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0188]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0190]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0190]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0189]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0190]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0190]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0190]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0190]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0190]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0190]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0190]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0195]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0190]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0194]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0190]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
#   0%|          | 0/5 [00:00<?, ?it/s]
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0194]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0194]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0195]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0198]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0195]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0195]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0196]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0197]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0194]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0195]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0194]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0195]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0194]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0195]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0194]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0195]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0194]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0195]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0195]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0195]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0189]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0189]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0193]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0191]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0192]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# ++++++++++++++++++++++++++++++ CategoricalHead(
#   (linear): Linear(in_features=256, out_features=4, bias=True)
# ) ScalarHead(
#   (linear): Linear(in_features=256, out_features=1, bias=True)
# )
# hey
# ========== CategoricalDist(logits: torch.Size([1, 4])) tensor([[-0.0194]]) <class 'rl2.utils.distributions.CategoricalDist'> <class 'torch.Tensor'>
# [<class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>, <class 'torch.Tensor'>]
# (((((((((( forward
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-d83854e5a335> in <module>
#       5 for step in tqdm(range(5)):
#       6 #     if train_fn is None:
# ----> 7     agent.train()
#       8 #     else:
#       9 #         train_fn(agent, step, steps)
#
# <ipython-input-7-95118b892074> in train(self)
#      23
#      24     def train(self):
# ---> 25         self.collector.step_env()
#      26         for epoch in range(self.epoch):
#      27             self.collector.reset_count()
#
# ~/PycharmProjects/rl2/rl2/collectors/pg_collector.py in step_env(self, logger, info)
#      52             v = torch.from_numpy(np.asarray(v))
#      53             self.buffer[k] = v.float().to(self.device)
# ---> 54         self.buffer['advs'] = self.compute_advantage()
#      55
#      56         for k, v in self.buffer.items():
#
# ~/PycharmProjects/rl2/rl2/collectors/pg_collector.py in compute_advantage(self, **kwargs)
#     144                 _nonterminal = 1.0 - self.buffer['dones'][t + 1].float()
#     145
# --> 146             while len(_nonterminal.shape) < len(_vals.shape):
#     147                 _nonterminal = _nonterminal.unsqueeze(1)
#     148             rews = self.buffer['rews'][t]
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'shape'

# %%
model = agent.model

# %%
input_shape

# %%
example_inputs = torch.rand((32,*input_shape)).to(device)
example_inputs.shape

# %%
model

# %%
#1 torch.save
torch.save(agent.model, 'just_prms.pt')

#ok

# %%
#2 torch.jit.script
sc = torch.jit.script(model)
torch.jit.save(sc, 'ppo_script.pt')

# %%
#3 torch.jit.trace
sc = torch.jit.trace(model, example_inputs)
torch.jit.save(sc, 'ppo_trace.pt')

# %%
#4 torch.jit.trace_module
sc = torch.jit.trace_module(model, #dict input)
torch.jit.save(sc, 'ppo_trace.pt')
